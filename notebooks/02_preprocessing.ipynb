# %%
import sys
import os

# Add project root to the Python path
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)

print("Project root added:", project_root)
# Out:
# Project root added: c:\Users\krish\Downloads\IR_Project\intelligent_recipe_assistant

# %%
import pandas as pd
from src.preprocessing import preprocess_dataframe

sample_df = pd.read_csv("../data/sample/sample_10000.csv")

processed_df = preprocess_dataframe(sample_df)

processed_df.to_csv("../data/preprocessed_10000.csv", index=False)

print("Preprocessing complete!")
processed_df.head()
# Out:
# Preprocessing complete!
#        id                                               name  minutes  \
# 0   94947                        crab filled crescent snacks       70
# 1  429010                                 curried bean salad       20
# 2  277542                delicious steak with onion marinade       25
# 3   78450                        pork tenderloin with hoisin       15
# 4   80012  mixed baby greens with oranges  grapefruit and...       15
#
#                                                 tags  \
# 0  ['time-to-make', 'course', 'main-ingredient', ...
# 1  ['curries', '30-minutes-or-less', 'time-to-mak...
# 2  ['lactose', '30-minutes-or-less', 'time-to-mak...
# 3  ['15-minutes-or-less', 'time-to-make', 'course...
# 4  ['15-minutes-or-less', 'time-to-make', 'course...
#
#                                          description  \
# 0          found in a crescent roll recipe magazine.
# 1  serve this flavorful and refreshing salad as a...
# 2  another i've not tried, but looks good! times ...
# 3  another keeper from bonnie stern's heartsmart ...
# 4  i love grapefruit in a salad and this one is p...
#
#                                          ingredients  \
# 0  ['crabmeat', 'cream cheese', 'green onions', '...
# 1  ['garbanzo beans', 'black beans', 'onion', 'gi...
# 2  ['olive oil', 'red onion', 'light brown sugar'...
# 3  ['pork tenderloin', 'soy sauce', 'hoisin sauce...
# 4  ['mixed baby greens', 'oranges', 'grapefruit',...
#
#                                                steps  \
# 0  ['heat over to 375 degrees', 'spray large cook...
# 1  ['drain & rinse beans', 'stir all ingredients ...
# 2  ['heat the oil in a heavy-based pan and cook t...
# 3  ['cut pork into 1 / 4-inch slices', 'in a larg...
# 4  ['in a salad bowl combine the lettuce with the...
#
#                                   ingredients_tokens  \
# 0  [crabmeat, cream, cheese, green, onion, garlic...
# 1  [garbanzo, bean, black, bean, onion, ginger, p...
# 2  [olive, oil, red, onion, light, brown, sugar, ...
# 3  [pork, tenderloin, soy, sauce, hoisin, sauce, ...
# 4  [mix, baby, green, orange, grapefruit, avocado...
#
#                                         steps_tokens  \
# 0  [heat, degree, spray, large, cookie, sheet, no...
# 1  [drain, rinse, bean, stir, ingredient, togethe...
# 2  [heat, oil, heavy, base, pan, cook, onion, low...
# 3  [cut, pork, inch, slice, large, bowl, combine,...
# 4  [salad, bowl, combine, lettuce, citrus, avocad...
#
#                                          search_text
# 0  crab fill crescent snack crab fill crescent sn...
# 1  curry bean salad curry bean salad garbanzo bea...
# 2  delicious steak onion marinade delicious steak...
# 3  pork tenderloin hoisin pork tenderloin hoisin ...
# 4  mix baby green orange grapefruit avocado mix b...
